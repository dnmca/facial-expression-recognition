# %%
import pandas as pd
import numpy as np
import keras
import matplotlib.pyplot as plt

from scipy.ndimage import rotate
from scipy.ndimage import gaussian_filter

import random

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
mapping = {
    0: 'Angry',
    1: 'Disgust',
    2: 'Fear',
    3: 'Happy',
    4: 'Sad',
    5: 'Surprise',
    6: 'Neutral'
}

imapping = {
    'Angry': 0,
    'Disgust': 1,
    'Fear': 2,
    'Happy': 3,
    'Sad': 4,
    'Surprise': 5,
    'Neutral': 6
}


def flip_horizontally(image):
    return np.flip(image, axis=1)


def add_noise(image):
    return image + np.random.poisson(image.astype('float64'))


def rotate_right(image, angle=-20):
    return rotate(image, angle, mode='reflect', reshape=False)


def rotate_left(image, angle=20):
    return rotate(image, angle, mode='reflect', reshape=False)


def add_blur(image):
    return gaussian_filter(image, sigma=1)


def find_subsets(df: pd.DataFrame, class_to_fraction: dict):
    """
    select random subsets for given classes with given fractions
    :param df: data
    :param class_to_fraction: dictionary {'emotion' : fraction of the data to that is going to be augmented}
    :return: indices of the images to augmented
    """
    data = df.loc[df['y'].isin(class_to_fraction.keys())]
    indices = []
    for emotion in class_to_fraction.keys():
        temp = data.loc[data['y'] == emotion]
        indices = indices + random.sample(temp.index.tolist(), int(class_to_fraction[emotion] * len(temp)))

    return indices
  
class Augmenter:

    @staticmethod
    def augment_images(df: pd.DataFrame, 
                       target_file: str = None, 
                       class_to_fraction: dict = {'Disgust': 1}, 
                       augmentations: list = ['flip']) -> pd.DataFrame:

        # df = pd.read_csv(source_file)

        df['category'] = df['category'].str.strip()

        del df['Unnamed: 0']

        df['y'] = df['y'].map(mapping)

        indices = find_subsets(df, class_to_fraction)

        print(len(indices))
        temp = []

        if 'flip' in augmentations:
            for index in indices:
                temp.append([df.iloc[index, 0]] + flip_horizontally(
                    np.array(df.iloc[index, 1:2305]).reshape((48, 48))).flatten().tolist() + [df.iloc[index, 2305]])

        if 'noise' in augmentations:
            for index in indices:
                temp.append([df.iloc[index, 0]] + add_noise(
                    np.array(df.iloc[index, 1:2305]).reshape((48, 48))).flatten().tolist() + [df.iloc[index, 2305]])

        if 'rotate_right' in augmentations:
            for index in indices:
                temp.append([df.iloc[index, 0]] + rotate_right(
                    np.array(df.iloc[index, 1:2305], dtype='int').reshape((48, 48))).flatten().tolist() + [df.iloc[index, 2305]])

        if 'rotate_left' in augmentations:
            for index in indices:
                temp.append([df.iloc[index, 0]] + rotate_left(
                    np.array(df.iloc[index, 1:2305], dtype='int').reshape((48, 48))).flatten().tolist() + [df.iloc[index, 2305]])

        if 'blur' in augmentations:
            for index in indices:
                temp.append([df.iloc[index, 0]] + add_blur(
                    np.array(df.iloc[index, 1:2305], dtype='int').reshape((48, 48))).flatten().tolist() + [df.iloc[index, 2305]])

        print(len(temp))

        data = pd.DataFrame(temp, columns=df.columns)

        if target_file:
            data.to_csv(target_file)

        return data

# %%
df = pd.read_csv('emotions.csv')

ctf = {
    'Disgust': 1,
    'Fear': 0.5,
    'Angry': 0.5,
    'Surprise': 0.1,
    'Happy': 0.1,
    'Sad': 0.1,
    'Neutral': 0.1
}

df['category'] = df['category'].str.strip()

train = df.loc[df.category == 'Training',:]
valid = df.loc[df.category == 'PublicTest',:]
test  = df.loc[df.category == 'PrivateTest',:]

aug = Augmenter.augment_images(train.copy(), None, ctf, ['flip', 'rotate_right', 'rotate_left', 'blur', 'noise'])

del train['Unnamed: 0']
del valid['Unnamed: 0']
del test['Unnamed: 0']

aug['y'] = aug['y'].map(imapping)

train = train.append(aug.sample(frac=1), ignore_index=True)

X_train = np.array(train.iloc[:, 1:2305])
y_train = np.array(train.loc[:, ['y']])

X_val = np.array(valid.iloc[:, 1:2305])
y_val = np.array(valid.loc[:, ['y']])

X_test = np.array(test.iloc[:, 1:2305])
y_test = np.array(test.loc[:, ['y']])

del train
del valid
del test
# Out:
# 6498
# 32490

# %%
y_train = keras.utils.to_categorical(y_train, 7)
y_val = keras.utils.to_categorical(y_val, 7)
y_test = keras.utils.to_categorical(y_test, 7)

X_train_r = X_train.reshape((len(X_train), 48, 48))
X_val_r   = X_val.reshape((len(X_val), 48, 48))
X_test_r   = X_test.reshape((len(X_test), 48, 48))

del X_train
del X_val
del X_test

X_train_r = X_train_r / 255
X_val_r = X_val_r / 255
X_test_r = X_test_r / 255

# X_train_rgb = np.stack((X_train_r,) * 3, axis = -1)
# X_val_rgb = np.stack((X_val_r, ) * 3, axis = -1)
# X_test_rgb = np.stack((X_test_r, ) * 3, axis = -1)

X_train_bw = X_train_r.reshape((len(X_train_r), 48, 48, 1))
X_val_bw = X_val_r.reshape((len(X_val_r), 48, 48, 1))
X_test_bw = X_test_r.reshape((len(X_test_r), 48, 48, 1))

# %%
from keras import backend as K
from keras.applications.vgg19 import VGG19

from keras.metrics import categorical_accuracy

from keras.optimizers import Adam

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras import optimizers

np.random.seed(100)

# %% [markdown]
# ### Alexnet model

# %%
model = Sequential()

model.add(Conv2D(96,(5,5), padding='same', input_shape=(48, 48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(2,2), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(384,(2,2), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Conv2D(384,(2,2), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Conv2D(256,(2,2), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(1024))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[categorical_accuracy])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 48, 48, 96)        2496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 48, 48, 96)        384
# _________________________________________________________________
# activation_1 (Activation)    (None, 48, 48, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 96)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 256)       98560
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 256)       1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 24, 24, 256)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 12, 12, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 12, 12, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 6, 6, 384)         393600
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# activation_4 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 384)         590208
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 384)         1536
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 256)         393472
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 6, 6, 256)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2360320
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_7 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_8 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 3591
# =================================================================
# Total params: 5,234,503
# Trainable params: 5,227,143
# Non-trainable params: 7,360
# _________________________________________________________________

# %%
model.load_weights('alexnet.h5')

# %%
history = model.fit(X_train_bw, y_train, batch_size=256, epochs=100, validation_data=(X_val_bw, y_val))
# Out:
# Train on 61199 samples, validate on 3589 samples
# Epoch 1/100
# 61199/61199 [==============================] - 95s 2ms/step - loss: 1.1112 - categorical_accuracy: 0.6237 - val_loss: 1.0871 - val_categorical_accuracy: 0.6071
# Epoch 2/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.9450 - categorical_accuracy: 0.6543 - val_loss: 1.0153 - val_categorical_accuracy: 0.6439
# Epoch 3/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.9057 - categorical_accuracy: 0.6709 - val_loss: 1.0825 - val_categorical_accuracy: 0.6328
# Epoch 4/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8955 - categorical_accuracy: 0.6738 - val_loss: 1.2363 - val_categorical_accuracy: 0.5701
# Epoch 5/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8711 - categorical_accuracy: 0.6832 - val_loss: 1.0383 - val_categorical_accuracy: 0.6453
# Epoch 6/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8529 - categorical_accuracy: 0.6852 - val_loss: 1.1573 - val_categorical_accuracy: 0.6035
# Epoch 7/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8393 - categorical_accuracy: 0.6914 - val_loss: 1.0821 - val_categorical_accuracy: 0.6239
# Epoch 8/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8238 - categorical_accuracy: 0.6964 - val_loss: 1.0708 - val_categorical_accuracy: 0.6397
# Epoch 9/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.8111 - categorical_accuracy: 0.7014 - val_loss: 1.0736 - val_categorical_accuracy: 0.6252
# Epoch 10/100
# 61199/61199 [==============================] - 80s 1ms/step - loss: 0.7936 - categorical_accuracy: 0.7092 - val_loss: 1.0703 - val_categorical_accuracy: 0.6336
# Epoch 11/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7937 - categorical_accuracy: 0.7077 - val_loss: 1.0467 - val_categorical_accuracy: 0.6439
# Epoch 12/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7820 - categorical_accuracy: 0.7137 - val_loss: 1.1217 - val_categorical_accuracy: 0.6252
# Epoch 13/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7687 - categorical_accuracy: 0.7160 - val_loss: 1.1119 - val_categorical_accuracy: 0.6202
# Epoch 14/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7605 - categorical_accuracy: 0.7211 - val_loss: 1.0784 - val_categorical_accuracy: 0.6342
# Epoch 15/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7610 - categorical_accuracy: 0.7205 - val_loss: 1.1007 - val_categorical_accuracy: 0.6252
# Epoch 16/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7449 - categorical_accuracy: 0.7265 - val_loss: 1.0533 - val_categorical_accuracy: 0.6484
# Epoch 17/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7314 - categorical_accuracy: 0.7319 - val_loss: 1.0719 - val_categorical_accuracy: 0.6392
# Epoch 18/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7268 - categorical_accuracy: 0.7313 - val_loss: 1.1490 - val_categorical_accuracy: 0.6280
# Epoch 19/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7257 - categorical_accuracy: 0.7358 - val_loss: 1.0921 - val_categorical_accuracy: 0.6300
# Epoch 20/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7118 - categorical_accuracy: 0.7396 - val_loss: 1.0815 - val_categorical_accuracy: 0.6395
# Epoch 21/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7122 - categorical_accuracy: 0.7392 - val_loss: 1.0664 - val_categorical_accuracy: 0.6467
# Epoch 22/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.7005 - categorical_accuracy: 0.7431 - val_loss: 1.1550 - val_categorical_accuracy: 0.6222
# Epoch 23/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6938 - categorical_accuracy: 0.7455 - val_loss: 1.1264 - val_categorical_accuracy: 0.6300
# Epoch 24/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6873 - categorical_accuracy: 0.7474 - val_loss: 1.0906 - val_categorical_accuracy: 0.6428
# Epoch 25/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6798 - categorical_accuracy: 0.7500 - val_loss: 1.0763 - val_categorical_accuracy: 0.6439
# Epoch 26/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6889 - categorical_accuracy: 0.7483 - val_loss: 1.1496 - val_categorical_accuracy: 0.6113
# Epoch 27/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6776 - categorical_accuracy: 0.7507 - val_loss: 1.1434 - val_categorical_accuracy: 0.6289
# Epoch 28/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6626 - categorical_accuracy: 0.7571 - val_loss: 1.0675 - val_categorical_accuracy: 0.6498
# Epoch 29/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6579 - categorical_accuracy: 0.7594 - val_loss: 1.2100 - val_categorical_accuracy: 0.5963
# Epoch 30/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6545 - categorical_accuracy: 0.7612 - val_loss: 1.1261 - val_categorical_accuracy: 0.6294
# Epoch 31/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6556 - categorical_accuracy: 0.7612 - val_loss: 1.1297 - val_categorical_accuracy: 0.6372
# Epoch 32/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6401 - categorical_accuracy: 0.7653 - val_loss: 1.4286 - val_categorical_accuracy: 0.5525
# Epoch 33/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6636 - categorical_accuracy: 0.7575 - val_loss: 1.0646 - val_categorical_accuracy: 0.6517
# Epoch 34/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6428 - categorical_accuracy: 0.7653 - val_loss: 1.0846 - val_categorical_accuracy: 0.6453
# Epoch 35/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6352 - categorical_accuracy: 0.7669 - val_loss: 1.1893 - val_categorical_accuracy: 0.6177
# Epoch 36/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6312 - categorical_accuracy: 0.7690 - val_loss: 1.1329 - val_categorical_accuracy: 0.6397
# Epoch 37/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6211 - categorical_accuracy: 0.7727 - val_loss: 1.1159 - val_categorical_accuracy: 0.6439
# Epoch 38/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6225 - categorical_accuracy: 0.7733 - val_loss: 1.0986 - val_categorical_accuracy: 0.6456
# Epoch 39/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.6139 - categorical_accuracy: 0.7761 - val_loss: 1.1468 - val_categorical_accuracy: 0.6392
# Epoch 40/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6044 - categorical_accuracy: 0.7801 - val_loss: 1.1918 - val_categorical_accuracy: 0.6286
# Epoch 41/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.6062 - categorical_accuracy: 0.7785 - val_loss: 1.1322 - val_categorical_accuracy: 0.6445
# Epoch 42/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5967 - categorical_accuracy: 0.7809 - val_loss: 1.1359 - val_categorical_accuracy: 0.6459
# Epoch 43/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5932 - categorical_accuracy: 0.7822 - val_loss: 1.1689 - val_categorical_accuracy: 0.6411
# Epoch 44/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5917 - categorical_accuracy: 0.7830 - val_loss: 1.1358 - val_categorical_accuracy: 0.6403
# Epoch 45/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5855 - categorical_accuracy: 0.7862 - val_loss: 1.1504 - val_categorical_accuracy: 0.6403
# Epoch 46/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5805 - categorical_accuracy: 0.7883 - val_loss: 1.1404 - val_categorical_accuracy: 0.6442
# Epoch 47/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5778 - categorical_accuracy: 0.7884 - val_loss: 1.2179 - val_categorical_accuracy: 0.6252
# Epoch 48/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5745 - categorical_accuracy: 0.7913 - val_loss: 1.1244 - val_categorical_accuracy: 0.6495
# Epoch 49/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5639 - categorical_accuracy: 0.7946 - val_loss: 1.2111 - val_categorical_accuracy: 0.6303
# Epoch 50/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5784 - categorical_accuracy: 0.7890 - val_loss: 1.1489 - val_categorical_accuracy: 0.6475
# Epoch 51/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5641 - categorical_accuracy: 0.7941 - val_loss: 1.1387 - val_categorical_accuracy: 0.6445
# Epoch 52/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5591 - categorical_accuracy: 0.7974 - val_loss: 1.1693 - val_categorical_accuracy: 0.6395
# Epoch 53/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5583 - categorical_accuracy: 0.7970 - val_loss: 1.1981 - val_categorical_accuracy: 0.6300
# Epoch 54/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5558 - categorical_accuracy: 0.7976 - val_loss: 1.1588 - val_categorical_accuracy: 0.6434
# Epoch 55/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5508 - categorical_accuracy: 0.7986 - val_loss: 1.1472 - val_categorical_accuracy: 0.6414
# Epoch 56/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5441 - categorical_accuracy: 0.8032 - val_loss: 1.2567 - val_categorical_accuracy: 0.6183
# Epoch 57/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5407 - categorical_accuracy: 0.8028 - val_loss: 1.1433 - val_categorical_accuracy: 0.6562
# Epoch 58/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5407 - categorical_accuracy: 0.8017 - val_loss: 1.2120 - val_categorical_accuracy: 0.6330
# Epoch 59/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5345 - categorical_accuracy: 0.8073 - val_loss: 1.1641 - val_categorical_accuracy: 0.6495
# Epoch 60/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5357 - categorical_accuracy: 0.8050 - val_loss: 1.2278 - val_categorical_accuracy: 0.6272
# Epoch 61/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5669 - categorical_accuracy: 0.7945 - val_loss: 1.1807 - val_categorical_accuracy: 0.6484
# Epoch 62/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5301 - categorical_accuracy: 0.8056 - val_loss: 1.1508 - val_categorical_accuracy: 0.6506
# Epoch 63/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5340 - categorical_accuracy: 0.8071 - val_loss: 1.1285 - val_categorical_accuracy: 0.6598
# Epoch 64/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5321 - categorical_accuracy: 0.8083 - val_loss: 1.1838 - val_categorical_accuracy: 0.6411
# Epoch 65/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5307 - categorical_accuracy: 0.8064 - val_loss: 1.2019 - val_categorical_accuracy: 0.6389
# Epoch 66/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5168 - categorical_accuracy: 0.8109 - val_loss: 1.2319 - val_categorical_accuracy: 0.6431
# Epoch 67/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.5168 - categorical_accuracy: 0.8155 - val_loss: 1.1614 - val_categorical_accuracy: 0.6528
# Epoch 68/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5176 - categorical_accuracy: 0.8134 - val_loss: 1.2237 - val_categorical_accuracy: 0.6339
# Epoch 69/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5099 - categorical_accuracy: 0.8157 - val_loss: 1.2274 - val_categorical_accuracy: 0.6308
# Epoch 70/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5035 - categorical_accuracy: 0.8182 - val_loss: 1.2030 - val_categorical_accuracy: 0.6408
# Epoch 71/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5029 - categorical_accuracy: 0.8173 - val_loss: 1.2126 - val_categorical_accuracy: 0.6358
# Epoch 72/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.5064 - categorical_accuracy: 0.8167 - val_loss: 1.1516 - val_categorical_accuracy: 0.6553
# Epoch 73/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4980 - categorical_accuracy: 0.8211 - val_loss: 1.2205 - val_categorical_accuracy: 0.6392
# Epoch 74/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4996 - categorical_accuracy: 0.8182 - val_loss: 1.2409 - val_categorical_accuracy: 0.6291
# Epoch 75/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4965 - categorical_accuracy: 0.8208 - val_loss: 1.1727 - val_categorical_accuracy: 0.6573
# Epoch 76/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4887 - categorical_accuracy: 0.8236 - val_loss: 1.2293 - val_categorical_accuracy: 0.6395
# Epoch 77/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4828 - categorical_accuracy: 0.8252 - val_loss: 1.2203 - val_categorical_accuracy: 0.6431
# Epoch 78/100
# 61199/61199 [==============================] - 79s 1ms/step - loss: 0.4911 - categorical_accuracy: 0.8215 - val_loss: 1.2527 - val_categorical_accuracy: 0.6303
# Epoch 79/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4890 - categorical_accuracy: 0.8230 - val_loss: 1.1758 - val_categorical_accuracy: 0.6525
# Epoch 80/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4821 - categorical_accuracy: 0.8248 - val_loss: 1.2141 - val_categorical_accuracy: 0.6403
# Epoch 81/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4775 - categorical_accuracy: 0.8258 - val_loss: 1.3808 - val_categorical_accuracy: 0.6082
# Epoch 82/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4753 - categorical_accuracy: 0.8285 - val_loss: 1.2514 - val_categorical_accuracy: 0.6481
# Epoch 83/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4773 - categorical_accuracy: 0.8295 - val_loss: 1.1580 - val_categorical_accuracy: 0.6601
# Epoch 84/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4662 - categorical_accuracy: 0.8323 - val_loss: 1.2135 - val_categorical_accuracy: 0.6481
# Epoch 85/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4728 - categorical_accuracy: 0.8301 - val_loss: 1.2345 - val_categorical_accuracy: 0.6456
# Epoch 86/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4687 - categorical_accuracy: 0.8313 - val_loss: 1.2430 - val_categorical_accuracy: 0.6353
# Epoch 87/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4689 - categorical_accuracy: 0.8308 - val_loss: 1.1866 - val_categorical_accuracy: 0.6514
# Epoch 88/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4762 - categorical_accuracy: 0.8269 - val_loss: 1.2244 - val_categorical_accuracy: 0.6548
# Epoch 89/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4621 - categorical_accuracy: 0.8341 - val_loss: 1.2976 - val_categorical_accuracy: 0.6289
# Epoch 90/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4673 - categorical_accuracy: 0.8312 - val_loss: 1.1935 - val_categorical_accuracy: 0.6604
# Epoch 91/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4562 - categorical_accuracy: 0.8345 - val_loss: 1.2354 - val_categorical_accuracy: 0.6506
# Epoch 92/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4531 - categorical_accuracy: 0.8363 - val_loss: 1.2163 - val_categorical_accuracy: 0.6545
# Epoch 93/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4622 - categorical_accuracy: 0.8338 - val_loss: 1.2370 - val_categorical_accuracy: 0.6512
# Epoch 94/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4564 - categorical_accuracy: 0.8360 - val_loss: 1.2528 - val_categorical_accuracy: 0.6439
# Epoch 95/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4538 - categorical_accuracy: 0.8359 - val_loss: 1.2355 - val_categorical_accuracy: 0.6506
# Epoch 96/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4550 - categorical_accuracy: 0.8348 - val_loss: 1.2182 - val_categorical_accuracy: 0.6498
# Epoch 97/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4457 - categorical_accuracy: 0.8388 - val_loss: 1.2135 - val_categorical_accuracy: 0.6590
# Epoch 98/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4504 - categorical_accuracy: 0.8377 - val_loss: 1.3593 - val_categorical_accuracy: 0.6121
# Epoch 99/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4471 - categorical_accuracy: 0.8398 - val_loss: 1.2357 - val_categorical_accuracy: 0.6523
# Epoch 100/100
# 61199/61199 [==============================] - 78s 1ms/step - loss: 0.4462 - categorical_accuracy: 0.8388 - val_loss: 1.2868 - val_categorical_accuracy: 0.6353

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'categorical_accuracy', 'val_categorical_accuracy', 'loss'])

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# /usr/local/envs/py3env/lib/python3.5/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
model.evaluate(X_test_bw, y = y_test, verbose=1)
# Out:
# 3589/3589 [==============================] - 2s 578us/step
# [1.2168673389002487, 0.6430760657730857]

# %%
model.save_weights('augmented-alexnet.h5')

# %%
model_json = model.to_json()

with open("augmented-alexnet.json", "w") as json_file:
    json_file.write(model_json)
